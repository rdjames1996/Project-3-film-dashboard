# %%
# Dependencies
import requests
from config import api_key
import time
#url = “https://api.nytimes.com/svc/search/v2/articlesearch.json?”
url = "https://api.themoviedb.org/3/movie/"
import pprint
import random

# %%
for movieid in range(0,10):
    query_url = f"{url}{movieid+random.randint(250, 500)}?api_key={api_key}"
    articles = requests.get(query_url).json()
    pprint.pprint(articles)
# Out:
# {'status_code': 34,
#  'status_message': 'The resource you requested could not be found.',
#  'success': False}
# {'adult': False,
#  'backdrop_path': '/x7fK0oOUX8Ks1B1lZsACmCXUybI.jpg',
#  'belongs_to_collection': None,
#  'budget': 100000000,
#  'genres': [{'id': 28, 'name': 'Action'},
#             {'id': 14, 'name': 'Fantasy'},
#             {'id': 9648, 'name': 'Mystery'},
#             {'id': 80, 'name': 'Crime'}],
#  'homepage': '',
#  'id': 314,
#  'imdb_id': 'tt0327554',
#  'original_language': 'en',
#  'original_title': 'Catwoman',
#  'overview': 'A shy woman, endowed with the speed, reflexes, and senses of a '
#              'cat, walks a thin line between criminal and hero, even as a '
#              'detective doggedly pursues her, fascinated by both of her '
#              'personas',
#  'popularity': 25.169,
#  'poster_path': '/pvnPgukFyEKgCzyOxyLiwyZ8T1C.jpg',
#  'production_companies': [{'id': 79,
#                            'logo_path': '/tpFpsqbleCzEE2p5EgvUq6ozfCA.png',
#                            'name': 'Village Roadshow Pictures',
#                            'origin_country': 'US'},
#                           {'id': 174,
#                            'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png',
#                            'name': 'Warner Bros. Pictures',
#                            'origin_country': 'US'},
#                           {'id': 813,
#                            'logo_path': None,
#                            'name': 'Di Novi Pictures',
#                            'origin_country': 'US'},
#                           {'id': 52945,
#                            'logo_path': None,
#                            'name': 'Frantic Films',
#                            'origin_country': 'CA'},
#                           {'id': 52946,
#                            'logo_path': None,
#                            'name': 'Maple Shade Films',
#                            'origin_country': 'US'},
#                           {'id': 52947,
#                            'logo_path': None,
#                            'name': 'Catwoman Films',
#                            'origin_country': ''}],
#  'production_countries': [{'iso_3166_1': 'US',
#                            'name': 'United States of America'}],
#  'release_date': '2004-07-22',
#  'revenue': 82102379,
#  'runtime': 104,
#  'spoken_languages': [{'english_name': 'Spanish',
#                        'iso_639_1': 'es',
#                        'name': 'Español'},
#                       {'english_name': 'English',
#                        'iso_639_1': 'en',
#                        'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'You can’t CATch her.',
#  'title': 'Catwoman',
#  'video': False,
#  'vote_average': 4.593,
#  'vote_count': 2943}
# {'adult': False,
#  'backdrop_path': '/3EJ7lQ9VOnvFLv2KrJOtlGA3uzT.jpg',
#  'belongs_to_collection': None,
#  'budget': 14000000,
#  'genres': [{'id': 18, 'name': 'Drama'},
#             {'id': 53, 'name': 'Thriller'},
#             {'id': 80, 'name': 'Crime'}],
#  'homepage': '',
#  'id': 379,
#  'imdb_id': 'tt0100150',
#  'original_language': 'en',
#  'original_title': "Miller's Crossing",
#  'overview': 'Set in 1929, a political boss and his advisor have a parting of '
#              'the ways when they both fall for the same woman.',
#  'popularity': 12.692,
#  'poster_path': '/i83gYdglRCjCRLSsmCk5nRWRmDM.jpg',
#  'production_companies': [{'id': 25,
#                            'logo_path': '/qZCc1lty5FzX30aOCVRBLzaVmcp.png',
#                            'name': '20th Century Fox',
#                            'origin_country': 'US'},
#                           {'id': 11273,
#                            'logo_path': None,
#                            'name': 'Circle Films',
#                            'origin_country': ''}],
#  'production_countries': [{'iso_3166_1': 'US',
#                            'name': 'United States of America'}],
#  'release_date': '1990-09-21',
#  'revenue': 5080409,
#  'runtime': 115,
#  'spoken_languages': [{'english_name': 'English',
#                        'iso_639_1': 'en',
#                        'name': 'English'},
#                       {'english_name': 'Irish',
#                        'iso_639_1': 'ga',
#                        'name': 'Gaeilge'},
#                       {'english_name': 'Italian',
#                        'iso_639_1': 'it',
#                        'name': 'Italiano'},
#                       {'english_name': 'Yiddish',
#                        'iso_639_1': 'yi',
#                        'name': ''}],
#  'status': 'Released',
#  'tagline': 'Up is down, black is white, and nothing is what it seems.',
#  'title': "Miller's Crossing",
#  'video': False,
#  'vote_average': 7.489,
#  'vote_count': 1375}
# {'adult': False,
#  'backdrop_path': '/65VvjEscRHZNCCg63GmRfGU66v9.jpg',
#  'belongs_to_collection': None,
#  'budget': 900000,
#  'genres': [{'id': 18, 'name': 'Drama'}],
#  'homepage': '',
#  'id': 266,
#  'imdb_id': 'tt0057345',
#  'original_language': 'fr',
#  'original_title': 'Le Mépris',
#  'overview': 'A philistine in the art film business, Jeremy Prokosch is a '
#              'producer unhappy with the work of his director. Prokosch has '
#              'hired Fritz Lang to direct an adaptation of "The Odyssey," but '
#              'when it seems that the legendary filmmaker is making a picture '
#              'destined to bomb at the box office, he brings in a screenwriter '
#              'to energize the script. The professional intersects with the '
#              'personal when a rift develops between the writer and his wife.',
#  'popularity': 10.819,
#  'poster_path': '/aQUDdxuWQvXMGzZw0VmvGYrPtk9.jpg',
#  'production_companies': [{'id': 109,
#                            'logo_path': None,
#                            'name': 'Rome Paris Films',
#                            'origin_country': ''},
#                           {'id': 1714,
#                            'logo_path': None,
#                            'name': 'Les Films Concordia',
#                            'origin_country': 'FR'},
#                           {'id': 10000,
#                            'logo_path': None,
#                            'name': 'Compagnia Cinematografica Champion',
#                            'origin_country': 'IT'}],
#  'production_countries': [{'iso_3166_1': 'FR', 'name': 'France'},
#                           {'iso_3166_1': 'IT', 'name': 'Italy'}],
#  'release_date': '1963-10-29',
#  'revenue': 528428,
#  'runtime': 103,
#  'spoken_languages': [{'english_name': 'English',
#                        'iso_639_1': 'en',
#                        'name': 'English'},
#                       {'english_name': 'French',
#                        'iso_639_1': 'fr',
#                        'name': 'Français'},
#                       {'english_name': 'German',
#                        'iso_639_1': 'de',
#                        'name': 'Deutsch'},
#                       {'english_name': 'Italian',
#                        'iso_639_1': 'it',
#                        'name': 'Italiano'}],
#  'status': 'Released',
#  'tagline': 'More Bold! More Brazen! And Much, Much More Bardot!',
#  'title': 'Contempt',
#  'video': False,
#  'vote_average': 7.139,
#  'vote_count': 669}
# {'adult': False,
#  'backdrop_path': '/2LDz3KmQ83EggYIiTwLvrZwWdA5.jpg',
#  'belongs_to_collection': None,
#  'budget': 8731048,
#  'genres': [{'id': 9648, 'name': 'Mystery'},
#             {'id': 18, 'name': 'Drama'},
#             {'id': 53, 'name': 'Thriller'}],
#  'homepage': 'http://www.cache-derfilm.at',
#  'id': 445,
#  'imdb_id': 'tt0387898',
#  'original_language': 'fr',
#  'original_title': 'Caché',
#  'overview': 'A married couple is terrorized by a series of videotapes planted '
#              'on their front porch.',
#  'popularity': 10.917,
#  'poster_path': '/oTAe1aW9IWjnY4ZW1YRx6UaXM2f.jpg',
#  'production_companies': [{'id': 46,
#                            'logo_path': '/3xFdKHLXPGHEbrAkmsepGE8974Y.png',
#                            'name': 'WDR',
#                            'origin_country': 'DE'},
#                           {'id': 94,
#                            'logo_path': '/huC7HqorvUThGIrENrbcHmQVUA0.png',
#                            'name': 'ARTE France Cinéma',
#                            'origin_country': 'FR'},
#                           {'id': 104,
#                            'logo_path': '/9aotxauvc9685tq9pTcRJszuT06.png',
#                            'name': 'Canal+',
#                            'origin_country': 'FR'},
#                           {'id': 223,
#                            'logo_path': '/b9Icqi8qGm7gJ6jVs8bauUo5N5Q.png',
#                            'name': 'Les Films du Losange',
#                            'origin_country': 'FR'},
#                           {'id': 224,
#                            'logo_path': None,
#                            'name': 'wega film vienna',
#                            'origin_country': 'AT'},
#                           {'id': 225,
#                            'logo_path': '/cmxkBc3dmwWaIHFCrkXZoAfGoOa.png',
#                            'name': 'BIM Distribuzione',
#                            'origin_country': 'IT'},
#                           {'id': 310,
#                            'logo_path': '/4Gp5A4YdjPBfsHT47ngHMaXWmb9.png',
#                            'name': 'CNC',
#                            'origin_country': 'FR'},
#                           {'id': 315,
#                            'logo_path': '/hdu0sVxgtCuQud0xF8ZBiN7hEhY.png',
#                            'name': 'Filmstiftung Nordrhein-Westfalen',
#                            'origin_country': 'DE'},
#                           {'id': 591,
#                            'logo_path': '/q5I5RDwMEiqoNmfaJgd2LraEOJY.png',
#                            'name': 'France 3 Cinéma',
#                            'origin_country': 'FR'},
#                           {'id': 694,
#                            'logo_path': '/5LEHONGkZBIoWvp1ygHOF8iyi1M.png',
#                            'name': 'StudioCanal',
#                            'origin_country': 'FR'},
#                           {'id': 850,
#                            'logo_path': '/aF7qajGJGtMpdrtvssM9g90YanX.png',
#                            'name': 'Eurimages',
#                            'origin_country': 'FR'},
#                           {'id': 1704,
#                            'logo_path': '/sb3PuMTgJgpPUY7x634etBAhodu.png',
#                            'name': 'Bavaria Film',
#                            'origin_country': 'DE'},
#                           {'id': 3391,
#                            'logo_path': '/t0QBs2fI3mE3HxgoH1n39bYuzNu.png',
#                            'name': 'ORF',
#                            'origin_country': 'AT'},
#                           {'id': 10273,
#                            'logo_path': None,
#                            'name': 'Filmfonds Wien',
#                            'origin_country': ''},
#                           {'id': 11389,
#                            'logo_path': '/eKVLElq1XAbcCcwnVj89G9EXRGB.png',
#                            'name': 'OFI',
#                            'origin_country': 'AT'}],
#  'production_countries': [{'iso_3166_1': 'AT', 'name': 'Austria'},
#                           {'iso_3166_1': 'FR', 'name': 'France'},
#                           {'iso_3166_1': 'DE', 'name': 'Germany'},
#                           {'iso_3166_1': 'IT', 'name': 'Italy'}],
#  'release_date': '2005-10-05',
#  'revenue': 36000000,
#  'runtime': 117,
#  'spoken_languages': [{'english_name': 'French',
#                        'iso_639_1': 'fr',
#                        'name': 'Français'}],
#  'status': 'Released',
#  'tagline': '',
#  'title': 'Caché',
#  'video': False,
#  'vote_average': 7.069,
#  'vote_count': 889}
# {'adult': False,
#  'backdrop_path': '/pP3fTbqsvpr9p0fc5tr7tJkdZqb.jpg',
#  'belongs_to_collection': None,
#  'budget': 50000000,
#  'genres': [{'id': 80, 'name': 'Crime'},
#             {'id': 18, 'name': 'Drama'},
#             {'id': 10751, 'name': 'Family'}],
#  'homepage': 'http://www.olivertwistthemovie.co.uk/',
#  'id': 257,
#  'imdb_id': 'tt0380599',
#  'original_language': 'en',
#  'original_title': 'Oliver Twist',
#  'overview': 'Oliver Twist the modern filmed version of Charles Dickens '
#              'bestseller, a Roman Polanski adaptation. The classic Dickens '
#              'tale, where an orphan meets a pickpocket on the streets of '
#              'London. From there, he joins a household of boys who are trained '
#              'to steal for their master.',
#  'popularity': 16.189,
#  'poster_path': '/zhPdYZ3x2uanhM1SyBj4CuL6hSa.jpg',
#  'production_companies': [{'id': 355,
#                            'logo_path': None,
#                            'name': 'R.P. Productions',
#                            'origin_country': 'FR'},
#                           {'id': 2979,
#                            'logo_path': None,
#                            'name': 'ETIC Films',
#                            'origin_country': ''},
#                           {'id': 6732,
#                            'logo_path': None,
#                            'name': 'Runteam III Ltd.',
#                            'origin_country': ''}],
#  'production_countries': [{'iso_3166_1': 'CZ', 'name': 'Czech Republic'},
#                           {'iso_3166_1': 'FR', 'name': 'France'},
#                           {'iso_3166_1': 'IT', 'name': 'Italy'},
#                           {'iso_3166_1': 'GB', 'name': 'United Kingdom'}],
#  'release_date': '2005-09-23',
#  'revenue': 42580321,
#  'runtime': 130,
#  'spoken_languages': [{'english_name': 'English',
#                        'iso_639_1': 'en',
#                        'name': 'English'}],
#  'status': 'Released',
#  'tagline': '',
#  'title': 'Oliver Twist',
#  'video': False,
#  'vote_average': 6.746,
#  'vote_count': 1045}
# {'adult': False,
#  'backdrop_path': '/oeT5amYwrZiaqsj4QKcOYYa5c5K.jpg',
#  'belongs_to_collection': None,
#  'budget': 0,
#  'genres': [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}],
#  'homepage': '',
#  'id': 469,
#  'imdb_id': 'tt0088184',
#  'original_language': 'en',
#  'original_title': 'Stranger Than Paradise',
#  'overview': 'Rootless Hungarian émigré Willie, his pal Eddie, and visiting '
#              'sixteen-year-old cousin Eva always manage to make the least of '
#              'any situation, whether aimlessly traversing the drab interiors '
#              'and environs of New York City, Cleveland, or an anonymous '
#              'Florida suburb.',
#  'popularity': 10.124,
#  'poster_path': '/Q9wdlNjBOti4JhAjAQXphzShw3.jpg',
#  'production_companies': [{'id': 49393,
#                            'logo_path': None,
#                            'name': 'Cinesthesia Productions',
#                            'origin_country': ''}],
#  'production_countries': [{'iso_3166_1': 'DE', 'name': 'Germany'},
#                           {'iso_3166_1': 'US',
#                            'name': 'United States of America'}],
#  'release_date': '1984-10-01',
#  'revenue': 0,
#  'runtime': 89,
#  'spoken_languages': [{'english_name': 'English',
#                        'iso_639_1': 'en',
#                        'name': 'English'},
#                       {'english_name': 'Hungarian',
#                        'iso_639_1': 'hu',
#                        'name': 'Magyar'}],
#  'status': 'Released',
#  'tagline': '',
#  'title': 'Stranger Than Paradise',
#  'video': False,
#  'vote_average': 7.194,
#  'vote_count': 428}
# {'status_code': 34,
#  'status_message': 'The resource you requested could not be found.',
#  'success': False}
# {'status_code': 34,
#  'status_message': 'The resource you requested could not be found.',
#  'success': False}
# {'adult': False,
#  'backdrop_path': '/o3PJPcTY40mUkj96P6wwhTIN9Rf.jpg',
#  'belongs_to_collection': None,
#  'budget': 0,
#  'genres': [{'id': 80, 'name': 'Crime'},
#             {'id': 18, 'name': 'Drama'},
#             {'id': 27, 'name': 'Horror'},
#             {'id': 53, 'name': 'Thriller'}],
#  'homepage': '',
#  'id': 467,
#  'imdb_id': 'tt0242527',
#  'original_language': 'en',
#  'original_title': 'The Hole',
#  'overview': 'Four teenagers at a British private school secretly uncover and '
#              'explore the depths of a sealed underground hole created decades '
#              'ago as a possible bomb shelter.',
#  'popularity': 11.461,
#  'poster_path': '/zVDhZHjcE0ksNfFSsJVoxDdAYCJ.jpg',
#  'production_companies': [{'id': 104,
#                            'logo_path': '/9aotxauvc9685tq9pTcRJszuT06.png',
#                            'name': 'Canal+',
#                            'origin_country': 'FR'},
#                           {'id': 245,
#                            'logo_path': '/9oyhlRJFKrGPmhbRseNbuD9H6dN.png',
#                            'name': 'Cowboy Films',
#                            'origin_country': 'GB'},
#                           {'id': 246,
#                            'logo_path': None,
#                            'name': 'Film Council',
#                            'origin_country': 'GB'},
#                           {'id': 247,
#                            'logo_path': None,
#                            'name': 'Granada Productions',
#                            'origin_country': 'GB'},
#                           {'id': 248,
#                            'logo_path': None,
#                            'name': 'Impact Pictures',
#                            'origin_country': 'GB'},
#                           {'id': 1178,
#                            'logo_path': None,
#                            'name': 'Pathé Pictures International',
#                            'origin_country': 'GB'},
#                           {'id': 7405,
#                            'logo_path': '/rfnws0uY8rsNAsrLbx3gEIcYXx3.png',
#                            'name': 'Dimension Films',
#                            'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}],
#  'release_date': '2001-04-20',
#  'revenue': 7819851,
#  'runtime': 102,
#  'spoken_languages': [{'english_name': 'English',
#                        'iso_639_1': 'en',
#                        'name': 'English'}],
#  'status': 'Released',
#  'tagline': "Once you get in, you can't get out.",
#  'title': 'The Hole',
#  'video': False,
#  'vote_average': 6.21,
#  'vote_count': 704}

# %%
# create a for loop to movies from the 2000 or later
release = []
# articles_list = articles["release_date"]
# print(articles_list)

for date in articles:
   release_date = requests.get(query_url["release_date"])
   print(release_date >= '2000-1-1')
   release.append(release_date.json())

release
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/j4/2y8t04qn1m97s814h363m1xc0000gn/T/ipykernel_4696/1490467915.py in <module>
#       5
#       6 for date in articles:
# ----> 7    release_date = requests.get(query_url["release_date"])
#       8    print(release_date >= '2000-1-1')
#       9    release.append(release_date.json())
#
# TypeError: string indices must be integers
