# %%
# Dependencies
import requests
from config import api_key
import time
#url = “https://api.nytimes.com/svc/search/v2/articlesearch.json?”
url = "https://api.themoviedb.org/3/movie/"
import pprint
import random
import pandas as pd

# %%
for movieid in range(0,20):
    #random.randint(a, b)
    query_url = f"{url}{movieid+random.randint(500, 900)}?api_key={api_key}"
    # create query with page number
    articles = requests.get(query_url).json()
    pprint.pprint(articles)
# Out:
# {'adult': False,
#  'backdrop_path': '/c6yfABGVKuB5cjoOwdX4AJMlzUz.jpg',
#  'belongs_to_collection': {'backdrop_path': '/6Jnlhr2ac8OuDJEowsFLzZY3SXd.jpg',
#                            'id': 2980,
#                            'name': 'Ghostbusters Collection',
#                            'poster_path': '/sctvCtE1M1rDF4f0W2fMrk2BrGB.jpg'},
#  'budget': 30000000,
#  'genres': [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'name': 'Fantasy'}],
#  'homepage': 'http://www.ghostbusters.com/',
#  'id': 620,
#  'imdb_id': 'tt0087332',
#  'original_language': 'en',
#  'original_title': 'Ghostbusters',
#  'overview': 'After losing their academic posts at a prestigious university, a '
#              'team of parapsychologists goes into business as '
#              'proton-pack-toting "ghostbusters" who exterminate ghouls, '
#              'hobgoblins and supernatural pests of all stripes. An ad campaign '
#              'pays off when a knockout cellist hires the squad to purge her '
#              'swanky digs of demons that appear to be living in her '
#              'refrigerator.',
#  'popularity': 30.541,
#  'poster_path': '/7E8nLijS9AwwUEPu2oFYOVKhdFA.jpg',
#  'production_companies': [{'id': 5,
#                            'logo_path': '/lieeAioEBVsgsoDT9HICrdt5iRa.png',
#                            'name': 'Columbia Pictures',
#                            'origin_country': 'US'},
#                           {'id': 4267,
#                            'logo_path': '/cw6C1E64Ckf5jV8ppAIz9gHaho4.png',
#                            'name': 'Delphi Films',
#                            'origin_country': 'US'},
#                           {'id': 47565,
#                            'logo_path': None,
#                            'name': 'Black Rhino Productions',
#                            'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#                            'name': 'United States of America'}],
#  'release_date': '1984-06-08',
#  'revenue': 296187079,
#  'runtime': 107,
#  'spoken_languages': [{'english_name': 'English',
#                        'iso_639_1': 'en',
#                        'name': 'English'}],
#  'status': 'Released',
#  'tagline': "They ain't afraid of no ghost.",
#  'title': 'Ghostbusters',
#  'video': False,
#  'vote_average': 7.464,
#  'vote_count': 7775}
# {'adult': False,
#  'backdrop_path': '/bIv1kaxb7tsiZYPO27PHfVb5eSF.jpg',
#  'belongs_to_collection': None,
#  'budget': 0,
#  'genres': [{'id': 28, 'name': 'Action'},
#             {'id': 80, 'name': 'Crime'},
#             {'id': 18, 'name': 'Drama'},
#             {'id': 53, 'name': 'Thriller'}],
#  'homepage': '',
#  'id': 877,
#  'imdb_id': 'tt0023427',
#  'original_language': 'en',
#  'original_title': 'Scarface',
#  'overview': 'In 1920s Chicago, Italian immigrant and notorious thug, Antonio '
#              '"Tony" Camonte, shoots his way to the top of the mobs while '
#              'trying to protect his sister from the criminal life.',
#  'popularity': 23.369,
#  'poster_path': '/y4E5oRiHMTFkEB12IIcpbKbKzDW.jpg',
#  'production_companies': [{'id': 60,
#                            'logo_path': '/1SEj4nyG3JPBSKBbFhtdcHRaIF9.png',
#                            'name': 'United Artists',
#                            'origin_country': 'US'},
#                           {'id': 13866,
#                            'logo_path': None,
#                            'name': 'The Caddo Company',
#                            'origin_country': ''}],
#  'production_countries': [{'iso_3166_1': 'US',
#                            'name': 'United States of America'}],
#  'release_date': '1932-04-09',
#  'revenue': 600000,
#  'runtime': 93,
#  'spoken_languages': [{'english_name': 'English',
#                        'iso_639_1': 'en',
#                        'name': 'English'},
#                       {'english_name': 'Italian',
#                        'iso_639_1': 'it',
#                        'name': 'Italiano'}],
#  'status': 'Released',
#  'tagline': 'The rise and fall of a power hungry mobster.',
#  'title': 'Scarface',
#  'video': False,
#  'vote_average': 7.5,
#  'vote_count': 485}
# {'adult': False,
#  'backdrop_path': '/4taRyneJlNDhuEkfX5QU6CG6Vbh.jpg',
#  'belongs_to_collection': None,
#  'budget': 7000000,
#  'genres': [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}],
#  'homepage': '',
#  'id': 535,
#  'imdb_id': 'tt0085549',
#  'original_language': 'en',
#  'original_title': 'Flashdance',
#  'overview': 'Alex Owens, a teen juggling between two odd jobs, aspires to '
#              'become a successful ballet dancer. Nick, who is her boss and '
#              'lover, supports and encourages her to fulfil her dream.',
#  'popularity': 21.613,
#  'poster_path': '/ziiy6ORt8BlxWFXskBChBMInvDA.jpg',
#  'production_companies': [{'id': 4,
#                            'logo_path': '/gz66EfNoYPqHTYI4q9UEN4CbHRc.png',
#                            'name': 'Paramount',
#                            'origin_country': 'US'},
#                           {'id': 1382,
#                            'logo_path': '/sOg7LGESPH5vCTOIdbMhLuypoLL.png',
#                            'name': 'PolyGram Filmed Entertainment',
#                            'origin_country': 'US'},
#                           {'id': 10288,
#                            'logo_path': None,
#                            'name': 'Don Simpson/Jerry Bruckheimer Films',
#                            'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#                            'name': 'United States of America'}],
#  'release_date': '1983-04-14',
#  'revenue': 201500000,
#  'runtime': 95,
#  'spoken_languages': [{'english_name': 'English',
#                        'iso_639_1': 'en',
#                        'name': 'English'}],
#  'status': 'Released',
#  'tagline': "She works in a man's world. She dances in the world of her "
#             'dreams.',
#  'title': 'Flashdance',
#  'video': False,
#  'vote_average': 6.5,
#  'vote_count': 1229}
# {'adult': False,
#  'backdrop_path': '/uif5fUshJrXyyDzfpzp1DLw3N0S.jpg',
#  'belongs_to_collection': {'backdrop_path': '/qawcCCyJNcdOpDRuXo5aJJycecY.jpg',
#                            'id': 119674,
#                            'name': 'Psycho Collection',
#                            'poster_path': '/2cFhmOImIv5VPbc2ieLRPCFacAh.jpg'},
#  'budget': 806947,
#  'genres': [{'id': 27, 'name': 'Horror'},
#             {'id': 18, 'name': 'Drama'},
#             {'id': 53, 'name': 'Thriller'}],
#  'homepage': '',
#  'id': 539,
#  'imdb_id': 'tt0054215',
#  'original_language': 'en',
#  'original_title': 'Psycho',
#  'overview': 'When larcenous real estate clerk Marion Crane goes on the lam '
#              'with a wad of cash and hopes of starting a new life, she ends up '
#              'at the notorious Bates Motel, where manager Norman Bates cares '
#              'for his housebound mother.',
#  'popularity': 40.304,
#  'poster_path': '/yz4QVqPx3h1hD1DfqqQkCq3rmxW.jpg',
#  'production_companies': [{'id': 10717,
#                            'logo_path': None,
#                            'name': 'Shamley Productions',
#                            'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#                            'name': 'United States of America'}],
#  'release_date': '1960-06-22',
#  'revenue': 0,
#  'runtime': 109,
#  'spoken_languages': [{'english_name': 'English',
#                        'iso_639_1': 'en',
#                        'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'A new—and altogether different—screen excitement!',
#  'title': 'Psycho',
#  'video': False,
#  'vote_average': 8.4,
#  'vote_count': 8764}
# {'adult': False,
#  'backdrop_path': '/xo2S7gRwCvWdVqM0Swv37yA2rzw.jpg',
#  'belongs_to_collection': None,
#  'budget': 35000000,
#  'genres': [{'id': 27, 'name': 'Horror'},
#             {'id': 9648, 'name': 'Mystery'},
#             {'id': 53, 'name': 'Thriller'}],
#  'homepage': '',
#  'id': 768,
#  'imdb_id': 'tt0120681',
#  'original_language': 'en',
#  'original_title': 'From Hell',
#  'overview': 'Frederick Abberline is an opium-huffing inspector from Scotland '
#              "Yard who falls for one of Jack the Ripper's prostitute targets "
#              'in this Hughes brothers adaption of a graphic novel that posits '
#              "the Ripper's true identity.",
#  'popularity': 21.414,
#  'poster_path': '/t2WpWM8nBO4sULXr2bDfNEt4qgr.jpg',
#  'production_companies': [{'id': 25,
#                            'logo_path': '/qZCc1lty5FzX30aOCVRBLzaVmcp.png',
#                            'name': '20th Century Fox',
#                            'origin_country': 'US'},
#                           {'id': 476,
#                            'logo_path': None,
#                            'name': 'Underworld Entertainment',
#                            'origin_country': ''}],
#  'production_countries': [{'iso_3166_1': 'CZ', 'name': 'Czech Republic'},
#                           {'iso_3166_1': 'US',
#                            'name': 'United States of America'},
#                           {'iso_3166_1': 'GB', 'name': 'United Kingdom'}],
#  'release_date': '2001-02-08',
#  'revenue': 74558115,
#  'runtime': 122,
#  'spoken_languages': [{'english_name': 'English',
#                        'iso_639_1': 'en',
#                        'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'Only the legend will survive.',
#  'title': 'From Hell',
#  'video': False,
#  'vote_average': 6.7,
#  'vote_count': 2446}
# {'adult': False,
#  'backdrop_path': '/x5VGdEBBGuhA0YRlk6dFFxGcamG.jpg',
#  'belongs_to_collection': None,
#  'budget': 70000000,
#  'genres': [{'id': 12, 'name': 'Adventure'},
#             {'id': 14, 'name': 'Fantasy'},
#             {'id': 35, 'name': 'Comedy'},
#             {'id': 10751, 'name': 'Family'}],
#  'homepage': '',
#  'id': 879,
#  'imdb_id': 'tt0102057',
#  'original_language': 'en',
#  'original_title': 'Hook',
#  'overview': "The boy who wasn't supposed grow up—Peter Pan—does just that, "
#              'becoming a soulless corporate lawyer whose workaholism could '
#              'cost him his wife and kids. During his trip to see Granny Wendy '
#              "in London, the vengeful Capt. Hook kidnaps Peter's kids and "
#              'forces Peter to return to Neverland.',
#  'popularity': 23.241,
#  'poster_path': '/a6rB1lGXoGms7gWxRfJneQmAjNV.jpg',
#  'production_companies': [{'id': 56,
#                            'logo_path': '/cEaxANEisCqeEoRvODv2dO1I0iI.png',
#                            'name': 'Amblin Entertainment',
#                            'origin_country': 'US'},
#                           {'id': 559,
#                            'logo_path': '/jqWioYeGSyTLuHth0141bTGvu6H.png',
#                            'name': 'TriStar Pictures',
#                            'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#                            'name': 'United States of America'}],
#  'release_date': '1991-04-10',
#  'revenue': 300855000,
#  'runtime': 142,
#  'spoken_languages': [{'english_name': 'English',
#                        'iso_639_1': 'en',
#                        'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'What if Peter Pan grew up?',
#  'title': 'Hook',
#  'video': False,
#  'vote_average': 6.8,
#  'vote_count': 4686}
# {'adult': False,
#  'backdrop_path': '/v9yXidPSqTjTDutxcBTnRqfDSpO.jpg',
#  'belongs_to_collection': None,
#  'budget': 3000000,
#  'genres': [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name': 'Drama'}],
#  'homepage': 'http://www.tsotsimovie.com/',
#  'id': 868,
#  'imdb_id': 'tt0468565',
#  'original_language': 'af',
#  'original_title': 'Tsotsi',
#  'overview': 'The South African multi-award winning film about a young South '
#              'African boy from the ghetto named Tsotsi, meaning Gangster. '
#              'Tsotsi, who left home as a child to get away from helpless '
#              'parents, finds a baby in the back seat of a car that he has just '
#              'stolen. He decides that it his responsibility to take care of '
#              'the baby and in the process learns that maybe the gangster life '
#              'isn’t the best way.',
#  'popularity': 7.157,
#  'poster_path': '/fvPGF7NYuZJACYVRAAF3FXicVf0.jpg',
#  'production_companies': [{'id': 563,
#                            'logo_path': None,
#                            'name': 'Movieworld Productions',
#                            'origin_country': ''},
#                           {'id': 565,
#                            'logo_path': None,
#                            'name': 'UK Film & TV Production Company',
#                            'origin_country': ''},
#                           {'id': 566,
#                            'logo_path': None,
#                            'name': 'National Film & Video Foundation of South '
#                                    'Africa',
#                            'origin_country': ''}],
#  'production_countries': [{'iso_3166_1': 'ZA', 'name': 'South Africa'},
#                           {'iso_3166_1': 'GB', 'name': 'United Kingdom'}],
#  'release_date': '2005-12-23',
#  'revenue': 9879971,
#  'runtime': 94,
#  'spoken_languages': [{'english_name': 'Afrikaans',
#                        'iso_639_1': 'af',
#                        'name': 'Afrikaans'},
#                       {'english_name': 'English',
#                        'iso_639_1': 'en',
#                        'name': 'English'},
#                       {'english_name': 'Xhosa', 'iso_639_1': 'xh', 'name': ''},
#                       {'english_name': 'Zulu',
#                        'iso_639_1': 'zu',
#                        'name': 'isiZulu'}],
#  'status': 'Released',
#  'tagline': 'In this world... Redemption comes just once.',
#  'title': 'Tsotsi',
#  'video': False,
#  'vote_average': 6.873,
#  'vote_count': 272}
# {'adult': False,
#  'backdrop_path': '/2Y0lMMmfbpMbVMgc86oi8o5cFQX.jpg',
#  'belongs_to_collection': None,
#  'budget': 14000000,
#  'genres': [{'id': 35, 'name': 'Comedy'},
#             {'id': 12, 'name': 'Adventure'},
#             {'id': 18, 'name': 'Drama'}],
#  'homepage': '',
#  'id': 864,
#  'imdb_id': 'tt0106611',
#  'original_language': 'en',
#  'original_title': 'Cool Runnings',
#  'overview': 'When a Jamaican sprinter is disqualified from the Olympic Games, '
#              'he enlists the help of a dishonored coach to start the first '
#              'Jamaican bobsled team.',
#  'popularity': 21.7,
#  'poster_path': '/6O4N3PSitItDo1v3PMDiltOqTI9.jpg',
#  'production_companies': [{'id': 2,
#                            'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png',
#                            'name': 'Walt Disney Pictures',
#                            'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#                            'name': 'United States of America'}],
#  'release_date': '1993-10-01',
#  'revenue': 154856263,
#  'runtime': 98,
#  'spoken_languages': [{'english_name': 'English',
#                        'iso_639_1': 'en',
#                        'name': 'English'},
#                       {'english_name': 'French',
#                        'iso_639_1': 'fr',
#                        'name': 'Français'},
#                       {'english_name': 'German',
#                        'iso_639_1': 'de',
#                        'name': 'Deutsch'},
#                       {'english_name': 'Russian',
#                        'iso_639_1': 'ru',
#                        'name': 'Pусский'}],
#  'status': 'Released',
#  'tagline': 'One dream. Four Jamaicans. Twenty below zero.',
#  'title': 'Cool Runnings',
#  'video': False,
#  'vote_average': 7.0,
#  'vote_count': 1724}
# {'adult': False,
#  'backdrop_path': '/m8mW6Faz4eXPamx0szTiA1cvdbF.jpg',
#  'belongs_to_collection': None,
#  'budget': 18000000,
#  'genres': [{'id': 14, 'name': 'Fantasy'},
#             {'id': 878, 'name': 'Science Fiction'},
#             {'id': 12, 'name': 'Adventure'}],
#  'homepage': '',
#  'id': 902,
#  'imdb_id': 'tt0112682',
#  'original_language': 'fr',
#  'original_title': 'La Cité des Enfants Perdus',
#  'overview': 'A scientist in a surrealist society kidnaps children to steal '
#              'their dreams, hoping that they slow his aging process.',
#  'popularity': 18.016,
#  'poster_path': '/whwT3Q9JxbAYzEc3t7uYYcCbTMf.jpg',
#  'production_companies': [{'id': 58,
#                            'logo_path': '/voYCwlBHJQANtjvm5MNIkCF1dDH.png',
#                            'name': 'Sony Pictures Classics',
#                            'origin_country': 'US'},
#                           {'id': 310,
#                            'logo_path': '/4Gp5A4YdjPBfsHT47ngHMaXWmb9.png',
#                            'name': 'CNC',
#                            'origin_country': 'FR'},
#                           {'id': 311,
#                            'logo_path': '/TNGvZ8zOklntjPP3EcsHtrR8Rc.png',
#                            'name': 'PROCIREP',
#                            'origin_country': 'FR'},
#                           {'id': 590,
#                            'logo_path': None,
#                            'name': 'Constellation Productions',
#                            'origin_country': ''},
#                           {'id': 591,
#                            'logo_path': '/q5I5RDwMEiqoNmfaJgd2LraEOJY.png',
#                            'name': 'France 3 Cinéma',
#                            'origin_country': 'FR'},
#                           {'id': 592,
#                            'logo_path': None,
#                            'name': 'Claudie Ossard Productions',
#                            'origin_country': ''},
#                           {'id': 694,
#                            'logo_path': '/5LEHONGkZBIoWvp1ygHOF8iyi1M.png',
#                            'name': 'StudioCanal',
#                            'origin_country': 'FR'},
#                           {'id': 850,
#                            'logo_path': '/aF7qajGJGtMpdrtvssM9g90YanX.png',
#                            'name': 'Eurimages',
#                            'origin_country': 'FR'},
#                           {'id': 851,
#                            'logo_path': None,
#                            'name': 'MEDIA Programme of the European Union',
#                            'origin_country': 'BE'},
#                           {'id': 981,
#                            'logo_path': '/pkrdO9ykplO4Zc8edikoSX5APUN.png',
#                            'name': 'TVE',
#                            'origin_country': 'ES'},
#                           {'id': 1871,
#                            'logo_path': None,
#                            'name': 'Cofimage 5',
#                            'origin_country': ''},
#                           {'id': 7237,
#                            'logo_path': None,
#                            'name': 'Tele München Fernseh '
#                                    'Produktionsgesellschaft (TMG)',
#                            'origin_country': 'DE'},
#                           {'id': 8170,
#                            'logo_path': None,
#                            'name': "Club d'Investissement Média",
#                            'origin_country': ''},
#                           {'id': 9335,
#                            'logo_path': None,
#                            'name': 'Canal+ España',
#                            'origin_country': 'ES'},
#                           {'id': 12009,
#                            'logo_path': None,
#                            'name': 'Elías Querejeta P. C.',
#                            'origin_country': 'ES'},
#                           {'id': 25020,
#                            'logo_path': None,
#                            'name': 'Victoires Productions',
#                            'origin_country': ''},
#                           {'id': 25021,
#                            'logo_path': None,
#                            'name': 'Constellation',
#                            'origin_country': ''},
#                           {'id': 25129,
#                            'logo_path': '/9kyYRk8aHbIdJCIj3cLh1f6FTXR.png',
#                            'name': 'Lumière Pictures',
#                            'origin_country': 'GB'},
#                           {'id': 68517,
#                            'logo_path': None,
#                            'name': 'Studio Image',
#                            'origin_country': ''},
#                           {'id': 79437,
#                            'logo_path': None,
#                            'name': 'Cofimage 4',
#                            'origin_country': ''},
#                           {'id': 79438,
#                            'logo_path': None,
#                            'name': 'Ossane',
#                            'origin_country': ''},
#                           {'id': 79439,
#                            'logo_path': None,
#                            'name': 'Phoenix Images',
#                            'origin_country': ''}],
#  'production_countries': [{'iso_3166_1': 'BE', 'name': 'Belgium'},
#                           {'iso_3166_1': 'FR', 'name': 'France'},
#                           {'iso_3166_1': 'DE', 'name': 'Germany'},
#                           {'iso_3166_1': 'ES', 'name': 'Spain'},
#                           {'iso_3166_1': 'GB', 'name': 'United Kingdom'}],
#  'release_date': '1995-08-17',
#  'revenue': 1738611,
#  'runtime': 108,
#  'spoken_languages': [{'english_name': 'Cantonese',
#                        'iso_639_1': 'cn',
#                        'name': '广州话 / 廣州話'},
#                       {'english_name': 'French',
#                        'iso_639_1': 'fr',
#                        'name': 'Français'}],
#  'status': 'Released',
#  'tagline': 'Where happily ever after is just a dream.',
#  'title': 'The City of Lost Children',
#  'video': False,
#  'vote_average': 7.323,
#  'vote_count': 892}
# {'adult': False,
#  'backdrop_path': None,
#  'belongs_to_collection': None,
#  'budget': 10000,
#  'genres': [],
#  'homepage': '',
#  'id': 538,
#  'imdb_id': 'tt0485662',
#  'original_language': 'en',
#  'original_title': 'Janine F.',
#  'overview': 'The humorous portrait of a female artist. The film follows the '
#              'career of 24-year-old Janine F. who in 2002 caused a commotion '
#              'from the rooftop of a Berlin building.',
#  'popularity': 1.4,
#  'poster_path': None,
#  'production_companies': [],
#  'production_countries': [{'iso_3166_1': 'DE', 'name': 'Germany'}],
#  'release_date': '2004-02-11',
#  'revenue': 0,
#  'runtime': 52,
#  'spoken_languages': [{'english_name': 'German',
#                        'iso_639_1': 'de',
#                        'name': 'Deutsch'}],
#  'status': 'Released',
#  'tagline': '',
#  'title': 'Janine F.',
#  'video': False,
#  'vote_average': 5.0,
#  'vote_count': 1}
# {'adult': False,
#  'backdrop_path': '/aFZS4Zyhi7FqIiv9M8CrmmkF5IR.jpg',
#  'belongs_to_collection': None,
#  'budget': 14000000,
#  'genres': [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}],
#  'homepage': '',
#  'id': 859,
#  'imdb_id': 'tt0094947',
#  'original_language': 'en',
#  'original_title': 'Dangerous Liaisons',
#  'overview': 'In 18th century France, Marquise de Merteuil asks her ex-lover '
#              'Vicomte de Valmont to seduce the future wife of another ex-lover '
#              'of hers in return for one last night with her. Yet things don’t '
#              'go as planned.',
#  'popularity': 14.82,
#  'poster_path': '/5MEl1xrbM93zjpFgS3sHJ2SlIFm.jpg',
#  'production_companies': [{'id': 174,
#                            'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png',
#                            'name': 'Warner Bros. Pictures',
#                            'origin_country': 'US'},
#                           {'id': 1176,
#                            'logo_path': None,
#                            'name': 'Lorimar Film Entertainment',
#                            'origin_country': 'US'},
#                           {'id': 18737,
#                            'logo_path': None,
#                            'name': 'NFH Films',
#                            'origin_country': ''}],
#  'production_countries': [{'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#                           {'iso_3166_1': 'US',
#                            'name': 'United States of America'}],
#  'release_date': '1988-12-21',
#  'revenue': 34670720,
#  'runtime': 119,
#  'spoken_languages': [{'english_name': 'English',
#                        'iso_639_1': 'en',
#                        'name': 'English'}],
#  'status': 'Released',
#  'tagline': "Lust. Seduction. Revenge. The game as you've never seen it played "
#             'before.',
#  'title': 'Dangerous Liaisons',
#  'video': False,
#  'vote_average': 7.257,
#  'vote_count': 971}
# {'adult': False,
#  'backdrop_path': '/inb0a3zdLW8GUDcfj7HNORTthrY.jpg',
#  'belongs_to_collection': None,
#  'budget': 0,
#  'genres': [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}],
#  'homepage': '',
#  'id': 697,
#  'imdb_id': 'tt0018217',
#  'original_language': 'ru',
#  'original_title': 'Октябрь',
#  'overview': "Sergei M. Eisenstein's docu-drama about the 1917 October "
#              'Revolution in Russia. Made ten years after the events and edited '
#              "in Eisenstein's 'Soviet Montage' style, it re-enacts in "
#              'celebratory terms several key scenes from the revolution.',
#  'popularity': 7.606,
#  'poster_path': '/tsfz9Ak1slSnxr6mSmRD3Wj7YZS.jpg',
#  'production_companies': [{'id': 410,
#                            'logo_path': '/eZlhJ4iCRM90hLB4RCC6RJEC9zr.png',
#                            'name': 'Sovkino',
#                            'origin_country': 'SU'}],
#  'production_countries': [{'iso_3166_1': 'SU', 'name': 'Soviet Union'}],
#  'release_date': '1928-01-20',
#  'revenue': 0,
#  'runtime': 115,
#  'spoken_languages': [{'english_name': 'No Language',
#                        'iso_639_1': 'xx',
#                        'name': 'No Language'}],
#  'status': 'Released',
#  'tagline': '',
#  'title': 'October (Ten Days that Shook the World)',
#  'video': False,
#  'vote_average': 7.0,
#  'vote_count': 165}
# {'adult': False,
#  'backdrop_path': '/fzJgCQh2NBnUYlms8EGyr4bPNz3.jpg',
#  'belongs_to_collection': None,
#  'budget': 1073000,
#  'genres': [{'id': 35, 'name': 'Comedy'}, {'id': 10749, 'name': 'Romance'}],
#  'homepage': '',
#  'id': 900,
#  'imdb_id': 'tt0029947',
#  'original_language': 'en',
#  'original_title': 'Bringing Up Baby',
#  'overview': 'David Huxley is waiting to get a bone he needs for his museum '
#              'collection. Through a series of strange circumstances, he meets '
#              'Susan Vance, and the duo have a series of misadventures which '
#              'include a leopard called Baby.',
#  'popularity': 11.612,
#  'poster_path': '/vTNNOtemaYmtx3k2NpsLMRJKEwZ.jpg',
#  'production_companies': [{'id': 6,
#                            'logo_path': '/n53F7K9scQWFXYbrCablqLKqJdp.png',
#                            'name': 'RKO Radio Pictures',
#                            'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#                            'name': 'United States of America'}],
#  'release_date': '1938-02-18',
#  'revenue': 0,
#  'runtime': 102,
#  'spoken_languages': [{'english_name': 'English',
#                        'iso_639_1': 'en',
#                        'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'And so begins the hilarious adventure of Professor David Huxley '
#             'and Miss Susan Vance, a flutter-brained vixen with love in her '
#             'heart!',
#  'title': 'Bringing Up Baby',
#  'video': False,
#  'vote_average': 7.564,
#  'vote_count': 803}
# {'status_code': 34,
#  'status_message': 'The resource you requested could not be found.',
#  'success': False}
# {'status_code': 34,
#  'status_message': 'The resource you requested could not be found.',
#  'success': False}
# {'adult': False,
#  'backdrop_path': '/bsI320Bb2X0nCSf1lZ9OqDo7dsR.jpg',
#  'belongs_to_collection': {'backdrop_path': '/5bPYYJTPwBum9DcuIV3luKffGYG.jpg',
#                            'id': 696110,
#                            'name': 'Miss Marple Collection',
#                            'poster_path': '/tJaL7nctFsHrqAzE2c1w06nlt6E.jpg'},
#  'budget': 0,
#  'genres': [{'id': 35, 'name': 'Comedy'},
#             {'id': 80, 'name': 'Crime'},
#             {'id': 18, 'name': 'Drama'},
#             {'id': 9648, 'name': 'Mystery'},
#             {'id': 53, 'name': 'Thriller'}],
#  'homepage': '',
#  'id': 751,
#  'imdb_id': 'tt0057334',
#  'original_language': 'en',
#  'original_title': 'Murder at the Gallop',
#  'overview': 'Miss Marple and Mr. Stringer are witnesses to the death by heart '
#              'attack of elderly, rich Mr. Enderby. Yet they have their doubts '
#              "about what happened. The police don't believe them, thus leading "
#              'Miss Marple to yet again investigate by herself.',
#  'popularity': 9.293,
#  'poster_path': '/lCLJ6yutSJc8PkiazcEh8dB6Juh.jpg',
#  'production_companies': [{'id': 5579,
#                            'logo_path': None,
#                            'name': 'Metro-Goldwyn-Mayer British Studios',
#                            'origin_country': ''},
#                           {'id': 14379,
#                            'logo_path': None,
#                            'name': 'George H. Brown Productions',
#                            'origin_country': ''}],
#  'production_countries': [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}],
#  'release_date': '1963-06-24',
#  'revenue': 0,
#  'runtime': 81,
#  'spoken_languages': [{'english_name': 'English',
#                        'iso_639_1': 'en',
#                        'name': 'English'}],
#  'status': 'Released',
#  'tagline': "It's a Penny to a Pony... Murder Will Out!",
#  'title': 'Murder at the Gallop',
#  'video': False,
#  'vote_average': 6.9,
#  'vote_count': 119}
# {'adult': False,
#  'backdrop_path': '/4YzGG8IPduUQRVnQ0vN5laHA1rH.jpg',
#  'belongs_to_collection': None,
#  'budget': 8000000,
#  'genres': [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}],
#  'homepage': 'http://www.foxsearchlight.com/littlemisssunshine/',
#  'id': 773,
#  'imdb_id': 'tt0449059',
#  'original_language': 'en',
#  'original_title': 'Little Miss Sunshine',
#  'overview': 'A family loaded with quirky, colorful characters piles into an '
#              'old van and road trips to California for little Olive to compete '
#              'in a beauty pageant.',
#  'popularity': 16.285,
#  'poster_path': '/tFnTds88mCuLcLPBseK1kF2E3qv.jpg',
#  'production_companies': [{'id': 43,
#                            'logo_path': '/4RgIPr55kBakgupWkzdDxqXJEqr.png',
#                            'name': 'Fox Searchlight Pictures',
#                            'origin_country': 'US'},
#                           {'id': 188,
#                            'logo_path': '/40E8iNvy6brH6t4BbmQL211jIpl.png',
#                            'name': 'Big Beach',
#                            'origin_country': 'US'},
#                           {'id': 2570,
#                            'logo_path': None,
#                            'name': 'Bona Fide Productions',
#                            'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#                            'name': 'United States of America'}],
#  'release_date': '2006-07-26',
#  'revenue': 100523181,
#  'runtime': 102,
#  'spoken_languages': [{'english_name': 'English',
#                        'iso_639_1': 'en',
#                        'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'A family on the verge of a breakdown',
#  'title': 'Little Miss Sunshine',
#  'video': False,
#  'vote_average': 7.671,
#  'vote_count': 6137}
# {'adult': False,
#  'backdrop_path': '/4H4RAeeykpi0ijvu3wYgV346y06.jpg',
#  'belongs_to_collection': {'backdrop_path': None,
#                            'id': 982426,
#                            'name': 'The Life of a Nation Collection',
#                            'poster_path': None},
#  'budget': 100000,
#  'genres': [{'id': 18, 'name': 'Drama'},
#             {'id': 36, 'name': 'History'},
#             {'id': 10752, 'name': 'War'}],
#  'homepage': '',
#  'id': 618,
#  'imdb_id': 'tt0004972',
#  'original_language': 'en',
#  'original_title': 'The Birth of a Nation',
#  'overview': 'Two families, abolitionist Northerners the Stonemans and '
#              'Southern landowners the Camerons, intertwine. When Confederate '
#              'colonel Ben Cameron is captured in battle, nurse Elsie Stoneman '
#              'petitions for his pardon. In Reconstruction-era South Carolina, '
#              "Cameron founds the Ku Klux Klan, battling Elsie's congressman "
#              'father and his African-American protégé, Silas Lynch.',
#  'popularity': 13.063,
#  'poster_path': '/pNpOXpQI5GSUfiWypubYtMh9928.jpg',
#  'production_companies': [{'id': 161894,
#                            'logo_path': None,
#                            'name': 'Epoch Film Co.',
#                            'origin_country': ''}],
#  'production_countries': [{'iso_3166_1': 'US',
#                            'name': 'United States of America'}],
#  'release_date': '1915-02-08',
#  'revenue': 11000000,
#  'runtime': 193,
#  'spoken_languages': [{'english_name': 'No Language',
#                        'iso_639_1': 'xx',
#                        'name': 'No Language'}],
#  'status': 'Released',
#  'tagline': 'The Fiery Cross of the Ku Klux Klan!',
#  'title': 'The Birth of a Nation',
#  'video': False,
#  'vote_average': 6.1,
#  'vote_count': 445}
# {'adult': False,
#  'backdrop_path': '/w2rWEjAMYErpNfoK2Z0GFh1LFhN.jpg',
#  'belongs_to_collection': None,
#  'budget': 44000000,
#  'genres': [{'id': 80, 'name': 'Crime'},
#             {'id': 18, 'name': 'Drama'},
#             {'id': 53, 'name': 'Thriller'}],
#  'homepage': '',
#  'id': 819,
#  'imdb_id': 'tt0117665',
#  'original_language': 'en',
#  'original_title': 'Sleepers',
#  'overview': 'Two gangsters seek revenge on the state jail worker who during '
#              'their stay at a youth prison sexually abused them. A sensational '
#              'court hearing takes place to charge him for the crimes.',
#  'popularity': 24.244,
#  'poster_path': '/eoYdbtJOvyshBgIEtsoH4uBEVR9.jpg',
#  'production_companies': [{'id': 174,
#                            'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png',
#                            'name': 'Warner Bros. Pictures',
#                            'origin_country': 'US'},
#                           {'id': 278,
#                            'logo_path': None,
#                            'name': 'Propaganda Films',
#                            'origin_country': ''},
#                           {'id': 11407,
#                            'logo_path': None,
#                            'name': 'Baltimore Pictures',
#                            'origin_country': ''}],
#  'production_countries': [{'iso_3166_1': 'US',
#                            'name': 'United States of America'}],
#  'release_date': '1996-10-18',
#  'revenue': 165615285,
#  'runtime': 147,
#  'spoken_languages': [{'english_name': 'English',
#                        'iso_639_1': 'en',
#                        'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'When friendship runs deeper than blood',
#  'title': 'Sleepers',
#  'video': False,
#  'vote_average': 7.595,
#  'vote_count': 3037}
# {'adult': False,
#  'backdrop_path': '/jeC1kzwWnZTuXl7xF4E5D70BD8c.jpg',
#  'belongs_to_collection': None,
#  'budget': 5985,
#  'genres': [{'id': 12, 'name': 'Adventure'},
#             {'id': 878, 'name': 'Science Fiction'}],
#  'homepage': '',
#  'id': 775,
#  'imdb_id': 'tt0000417',
#  'original_language': 'fr',
#  'original_title': 'Le Voyage dans la Lune',
#  'overview': 'Professor Barbenfouillis and five of his colleagues from the '
#              'Academy of Astronomy travel to the Moon aboard a rocket '
#              'propelled by a giant cannon. Once on the lunar surface, the bold '
#              'explorers face the many perils hidden in the caves of the '
#              'mysterious planet.',
#  'popularity': 16.702,
#  'poster_path': '/9o0v5LLFk51nyTBHZSre6OB37n2.jpg',
#  'production_companies': [{'id': 7159,
#                            'logo_path': None,
#                            'name': 'Star-Film',
#                            'origin_country': 'FR'}],
#  'production_countries': [{'iso_3166_1': 'FR', 'name': 'France'}],
#  'release_date': '1902-04-17',
#  'revenue': 0,
#  'runtime': 15,
#  'spoken_languages': [{'english_name': 'No Language',
#                        'iso_639_1': 'xx',
#                        'name': 'No Language'}],
#  'status': 'Released',
#  'tagline': '',
#  'title': 'A Trip to the Moon',
#  'video': False,
#  'vote_average': 7.9,
#  'vote_count': 1456}
